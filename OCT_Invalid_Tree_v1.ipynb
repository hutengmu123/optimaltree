# %%
from check_invalid_tree import *
data_list = data_processing()

# change the dtype to 'float64'
data_list[1][0] = data_list[1][0].astype('float64')
data_list[6][0] = data_list[6][0].astype('float64')

# %%
# test for data set 0
number_run = 50
invalid_depth3_0 = []
data_list_sample3_0 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result,aborted = fit_OCT(data_list=data_list, data_set=0, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_0.append(1)
    else:
        invalid_depth3_0.append(0)
        
    data_list_sample3_0.append(data_list)
        
invalid_depth4_0 = []
data_list_sample4_0 = []
for t in range(number_run):
    result,aborted = fit_OCT(data_list=data_list, data_set=0, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_0.append(1)
    else:
        invalid_depth4_0.append(0)
        
    data_list_sample4_0.append(data_list)
        
invalid_depth5_0 = []
data_list_sample5_0 = []
for t in range(number_run):
    result,aborted = fit_OCT(data_list=data_list, data_set=0, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_0.append(1)
    else:
        invalid_depth5_0.append(0)
        
    data_list_sample5_0.append(data_list)

# %%
print(sum(invalid_depth3_0))
print(sum(invalid_depth4_0))
print(sum(invalid_depth5_0))
print(aborted_status)

# %%
# test for data set 1
number_run = 50
invalid_depth3_1 = []
data_list_sample3_1 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=1, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_1.append(1)
    else:
        invalid_depth3_1.append(0)
        
    data_list_sample3_1.append(data_list)
        
invalid_depth4_1 = []
data_list_sample4_1 = []
for t in range(number_run):
    result,aborted = fit_OCT(data_list=data_list, data_set=1, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_1.append(1)
    else:
        invalid_depth4_1.append(0)
        
    data_list_sample4_1.append(data_list)
        
invalid_depth5_1 = []
data_list_sample5_1 = []
for t in range(number_run):
    result,aborted = fit_OCT(data_list=data_list, data_set=1, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_1.append(1)
    else:
        invalid_depth5_1.append(0)
        
    data_list_sample5_1.append(data_list)

# %%
print(sum(invalid_depth3_1))
print(sum(invalid_depth4_1))
print(sum(invalid_depth5_1))
print(aborted_status)

# %%
# test for data set 2
number_run = 50
invalid_depth3_2 = []
data_list_sample3_2 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result,aborted = fit_OCT(data_list=data_list, data_set=2, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_2.append(1)
    else:
        invalid_depth3_2.append(0)
        
    data_list_sample3_2.append(data_list)
        
invalid_depth4_2 = []
data_list_sample4_2 = []
for t in range(number_run):
    result,aborted = fit_OCT(data_list=data_list, data_set=2, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_2.append(1)
    else:
        invalid_depth4_2.append(0)
        
    data_list_sample4_2.append(data_list)
        
invalid_depth5_2 = []
data_list_sample5_2 = []
for t in range(number_run):
    result,aborted = fit_OCT(data_list=data_list, data_set=2, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_2.append(1)
    else:
        invalid_depth5_2.append(0)
        
    data_list_sample5_2.append(data_list)

# %%
print(sum(invalid_depth3_2))
print(sum(invalid_depth4_2))
print(sum(invalid_depth5_2))
print(aborted_status)

# %%
# test for data set 3
number_run = 50
invalid_depth3_3 = []
data_list_sample3_3 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=3, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_3.append(1)
    else:
        invalid_depth3_3.append(0)
        
    data_list_sample3_3.append(data_list)
        
invalid_depth4_3 = []
data_list_sample4_3 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=3, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_3.append(1)
    else:
        invalid_depth4_3.append(0)
        
    data_list_sample4_3.append(data_list)
        
invalid_depth5_3 = []
data_list_sample5_3 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=3, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_3.append(1)
    else:
        invalid_depth5_3.append(0)
        
    data_list_sample5_3.append(data_list)

# %%
print(sum(invalid_depth3_3))
print(sum(invalid_depth4_3))
print(sum(invalid_depth5_3))
print(aborted_status)

# %%
# test for data set 4
number_run = 50
invalid_depth3_4 = []
data_list_sample3_4 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=4, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_4.append(1)
    else:
        invalid_depth3_4.append(0)
        
    data_list_sample3_4.append(data_list)
        
invalid_depth4_4 = []
data_list_sample4_4 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=4, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_4.append(1)
    else:
        invalid_depth4_4.append(0)
        
    data_list_sample4_4.append(data_list)
        
invalid_depth5_4 = []
data_list_sample5_4 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=4, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_4.append(1)
    else:
        invalid_depth5_4.append(0)
        
    data_list_sample5_4.append(data_list)

# %%
print(sum(invalid_depth3_4))
print(sum(invalid_depth4_4))
print(sum(invalid_depth5_4))
print(aborted_status)

# %%
# test for data set 5
number_run = 50
invalid_depth3_5 = []
data_list_sample3_5 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=5, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_5.append(1)
    else:
        invalid_depth3_5.append(0)
        
    data_list_sample3_5.append(data_list)
        
invalid_depth4_5 = []
data_list_sample4_5 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=5, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_5.append(1)
    else:
        invalid_depth4_5.append(0)
        
    data_list_sample4_5.append(data_list)
        
invalid_depth5_5 = []
data_list_sample5_5 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=5, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_5.append(1)
    else:
        invalid_depth5_5.append(0)
        
    data_list_sample5_5.append(data_list)

# %%
print(sum(invalid_depth3_5))
print(sum(invalid_depth4_5))
print(sum(invalid_depth5_5))
print(aborted_status)

# %%
# test for data set 6
number_run = 50
invalid_depth3_6 = []
data_list_sample3_6 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=6, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_6.append(1)
    else:
        invalid_depth3_6.append(0)
        
    data_list_sample3_6.append(data_list)
        
invalid_depth4_6 = []
data_list_sample4_6 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=6, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_6.append(1)
    else:
        invalid_depth4_6.append(0)
        
    data_list_sample4_6.append(data_list)
        
invalid_depth5_6 = []
data_list_sample5_6 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=6, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_6.append(1)
    else:
        invalid_depth5_6.append(0)
        
    data_list_sample5_6.append(data_list)

# %%
print(sum(invalid_depth3_6))
print(sum(invalid_depth4_6))
print(sum(invalid_depth5_6))
print(aborted_status)

# %%
# test for data set 7
number_run = 50
invalid_depth3_7 = []
data_list_sample3_7 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=7, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_7.append(1)
    else:
        invalid_depth3_7.append(0)
        
    data_list_sample3_7.append(data_list)
        
invalid_depth4_7 = []
data_list_sample4_7 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=7, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_7.append(1)
    else:
        invalid_depth4_7.append(0)
        
    data_list_sample4_7.append(data_list)
        
invalid_depth5_7 = []
data_list_sample5_7 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=7, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_7.append(1)
    else:
        invalid_depth5_7.append(0)
        
    data_list_sample5_7.append(data_list)

# %%
print(sum(invalid_depth3_7))
print(sum(invalid_depth4_7))
print(sum(invalid_depth5_7))
print(aborted_status)

# %%
# test for data set 8
number_run = 50
invalid_depth3_8 = []
data_list_sample3_8 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=8, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_8.append(1)
    else:
        invalid_depth3_8.append(0)
        
    data_list_sample3_8.append(data_list)
        
invalid_depth4_8 = []
data_list_sample4_8 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=8, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_8.append(1)
    else:
        invalid_depth4_8.append(0)
        
    data_list_sample4_8.append(data_list)
        
invalid_depth5_8 = []
data_list_sample5_8 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=8, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_8.append(1)
    else:
        invalid_depth5_8.append(0)
        
    data_list_sample5_8.append(data_list)
# Out:
#    468   490    0.01000   52  316    0.90889    0.01000  98.9%   214   92s
#    595   532    0.01000   55  339    0.90889    0.01000  98.9%   192   99s
#    639   550    0.01000   61  360    0.90889    0.01000  98.9%   197  105s

# %%
print(sum(invalid_depth3_8))
print(sum(invalid_depth4_8))
print(sum(invalid_depth5_8))
print(aborted_status)

# %%
# test for data set 9
number_run = 50
invalid_depth3_9 = []
data_list_sample3_9 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=9, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_9.append(1)
    else:
        invalid_depth3_9.append(0)
        
    data_list_sample3_9.append(data_list)
        
invalid_depth4_9 = []
data_list_sample4_9 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=9, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_9.append(1)
    else:
        invalid_depth4_9.append(0)
        
    data_list_sample4_9.append(data_list)
        
invalid_depth5_9 = []
data_list_sample5_9 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=9, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_9.append(1)
    else:
        invalid_depth5_9.append(0)
        
    data_list_sample5_9.append(data_list)

# %%
print(sum(invalid_depth3_9))
print(sum(invalid_depth4_9))
print(sum(invalid_depth5_9))
print(aborted_status)

# %%
# test for data set 10
number_run = 50
invalid_depth3_10 = []
data_list_sample3_10 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=10, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_10.append(1)
    else:
        invalid_depth3_10.append(0)
        
    data_list_sample3_10.append(data_list)
        
invalid_depth4_10 = []
data_list_sample4_10 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=10, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_10.append(1)
    else:
        invalid_depth4_10.append(0)
        
    data_list_sample4_10.append(data_list)
        
invalid_depth5_10 = []
data_list_sample5_10 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=10, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_10.append(1)
    else:
        invalid_depth5_10.append(0)
        
    data_list_sample5_10.append(data_list)

# %%
print(sum(invalid_depth3_10))
print(sum(invalid_depth4_10))
print(sum(invalid_depth5_10))
print(aborted_status)

# %%
# test for data set 11
number_run = 50
invalid_depth3_11 = []
data_list_sample3_11 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=11, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_11.append(1)
    else:
        invalid_depth3_11.append(0)
        
    data_list_sample3_11.append(data_list)
        
invalid_depth4_11 = []
data_list_sample4_11 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=11, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_11.append(1)
    else:
        invalid_depth4_11.append(0)
        
    data_list_sample4_11.append(data_list)
        
invalid_depth5_11 = []
data_list_sample5_11 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=11, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_11.append(1)
    else:
        invalid_depth5_11.append(0)
        
    data_list_sample5_11.append(data_list)

# %%
print(sum(invalid_depth3_11))
print(sum(invalid_depth4_11))
print(sum(invalid_depth5_11))
print(aborted_status)

# %%
# test for data set 12
number_run = 50
invalid_depth3_12 = []
data_list_sample3_12 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=12, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_12.append(1)
    else:
        invalid_depth3_12.append(0)
        
    data_list_sample3_12.append(data_list)
        
invalid_depth4_12 = []
data_list_sample4_12 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=12, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_12.append(1)
    else:
        invalid_depth4_12.append(0)
        
    data_list_sample4_12.append(data_list)
        
invalid_depth5_12 = []
data_list_sample5_12 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=12, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_12.append(1)
    else:
        invalid_depth5_12.append(0)
        
    data_list_sample5_12.append(data_list)

# %%
print(sum(invalid_depth3_12))
print(sum(invalid_depth4_12))
print(sum(invalid_depth5_12))
print(aborted_status)

# %%
# test for data set 13
number_run = 50
invalid_depth3_13 = []
data_list_sample3_13 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=13, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_13.append(1)
    else:
        invalid_depth3_13.append(0)
        
    data_list_sample3_13.append(data_list)
        
invalid_depth4_13 = []
data_list_sample4_13 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=13, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_13.append(1)
    else:
        invalid_depth4_13.append(0)
        
    data_list_sample4_13.append(data_list)
        
invalid_depth5_13 = []
data_list_sample5_13 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=13, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_13.append(1)
    else:
        invalid_depth5_13.append(0)
        
    data_list_sample5_13.append(data_list)

# %%
print(sum(invalid_depth3_13))
print(sum(invalid_depth4_13))
print(sum(invalid_depth5_13))
print(aborted_status)

# %%
# test for data set 14
number_run = 50
invalid_depth3_14 = []
data_list_sample3_14 = []
aborted_status = {3:[],4:[],5:[]}
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=14, max_depth=3, small_epsilon=False, epsilon_version=False)
    aborted_status[3].append(aborted)
    if result.state ==1:
        invalid_depth3_14.append(1)
    else:
        invalid_depth3_14.append(0)
        
    data_list_sample3_14.append(data_list)
        
invalid_depth4_14 = []
data_list_sample4_14 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=14, max_depth=4, small_epsilon=False, epsilon_version=False)
    aborted_status[4].append(aborted)
    if result.state ==1:
        invalid_depth4_14.append(1)
    else:
        invalid_depth4_14.append(0)
        
    data_list_sample4_14.append(data_list)
        
invalid_depth5_14 = []
data_list_sample5_14 = []
for t in range(number_run):
    result, aborted = fit_OCT(data_list=data_list, data_set=14, max_depth=5, small_epsilon=False, epsilon_version=False)
    aborted_status[5].append(aborted)
    if result.state ==1:
        invalid_depth5_14.append(1)
    else:
        invalid_depth5_14.append(0)
        
    data_list_sample5_14.append(data_list)

# %%
print(sum(invalid_depth3_14))
print(sum(invalid_depth4_14))
print(sum(invalid_depth5_14))
print(aborted_status)
